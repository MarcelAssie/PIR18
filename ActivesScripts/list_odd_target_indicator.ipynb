# %%
import requests, pandas as pd
from bs4 import BeautifulSoup

# %%
def get_odd_target_indicator():
    url = 'https://unstats.un.org/sdgs/metadata'
    response = requests.get(url)

    
    if response.status_code == 200:
        soup = BeautifulSoup(response.content, 'html.parser')
        data = []

        panels_heading_default = soup.find_all('div', class_="panel panel-default")
        
        for panel in panels_heading_default:
            target_names = []
            odd = panel.find('h4').text.strip()
            targets = panel.find_all('h5')
            target_names.append([t.text.strip() for t in targets])
            ul_tags = panel.find_all('ul')
            for i in range(len(ul_tags)):
                indicators = ul_tags[i].find_all('small')
                for indicator in indicators:
                    indicator_text = ' '.join(indicator.stripped_strings)
                    if indicator_text.startswith("Indicator"):
                        parts = indicator_text.split()[1].split('.')
                        objectif = int(parts[0])
                        cible = parts[1] 
                        matching_target = next((target for target in target_names[0] if target.startswith(f'Target {objectif}.{cible}:')), None)
                        data.append({
                            'Objectif': odd.replace('Goal',''),
                            'Cible': matching_target.replace('Target',''),
                            'Indicateur': indicator_text.replace('Indicator','')
                        })
        df = pd.DataFrame(data)
        return df

    else:
        print("La requête a échoué avec le code d'état:", response.status_code)
        return None

# %%
get_odd_target_indicator()
# Out:
#                                               Objectif  \
# 0           1. End poverty in all its forms everywhere
# 1           1. End poverty in all its forms everywhere
# 2           1. End poverty in all its forms everywhere
# 3           1. End poverty in all its forms everywhere
# 4           1. End poverty in all its forms everywhere
# ..                                                 ...
# 244   17. Strengthen the means of implementation an...
# 245   17. Strengthen the means of implementation an...
# 246   17. Strengthen the means of implementation an...
# 247   17. Strengthen the means of implementation an...
# 248   17. Strengthen the means of implementation an...
#
#                                                  Cible  \
# 0     1.1: By 2030, eradicate extreme poverty for a...
# 1     1.2: By 2030, reduce at least by half the pro...
# 2     1.2: By 2030, reduce at least by half the pro...
# 3     1.3: Implement nationally appropriate social ...
# 4     1.4: By 2030, ensure that all men and women, ...
# ..                                                 ...
# 244   17.18: By 2020, enhance capacity-building sup...
# 245   17.18: By 2020, enhance capacity-building sup...
# 246   17.18: By 2020, enhance capacity-building sup...
# 247   17.19: By 2030, build on existing initiatives...
# 248   17.19: By 2030, build on existing initiatives...
#
#                                             Indicateur
# 0     1.1.1: Proportion of the population living be...
# 1     1.2.1: Proportion of population living below ...
# 2     1.2.2: Proportion of men, women and children ...
# 3     1.3.1: Proportion of population covered by so...
# 4     1.4.1: Proportion of population living in hou...
# ..                                                 ...
# 244           17.18.1: Statistical capacity indicators
# 245   17.18.2: Number of countries that have nation...
# 246   17.18.3: Number of countries with a national ...
# 247   17.19.1: Dollar value of all resources made a...
# 248   17.19.2: Proportion of countries that (a) hav...
#
# [249 rows x 3 columns]
