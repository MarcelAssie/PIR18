# %%
from keybert import KeyBERT
from sentence_transformers import SentenceTransformer
import os, sys
import pandas as pd
sys.path.append(os.path.abspath('..'))
from ActivesScripts.toolbox import read_txt_file, filter_similar_entities

# %%
def entities_extractions(dossier):
    """
    Extrait les mots-clés de fichiers texte dans un dossier et enregistre les résultats dans des fichiers séparés.

    Paramètres:
    dossier : str
        Chemin vers le dossier contenant les fichiers texte (.txt).
    """

    odd_number = dossier[-2:]

    print(f"\nDébut de traitement de l'ODD {odd_number}...")
    sentence_model = SentenceTransformer("all-MiniLM-L6-v2")

    # Liste des fichiers texte à traiter
    txt_files = [fichier for fichier in os.listdir(dossier)
                 if fichier.endswith(".txt") and "keywords" not in fichier]

    keywords_ODD = []

    for txt_file in txt_files:
        # Convertir le fichier texte en une chaîne de caractères
        texte = read_txt_file(f"{dossier}/{txt_file}")

        # Configurer le modèle KeyBert pour l'extraction des mots-clés
        kw_model = KeyBERT(model=sentence_model)
        keywords = kw_model.extract_keywords(
            texte,
            keyphrase_ngram_range=(1, 2),
            stop_words='english',
#             use_maxsum=True,
            nr_candidates=20,
            top_n=10
        )
        
        # Filtrer les entités similaires
        entities_filtered = filter_similar_entities(keywords, threshold=80)

        # Filtrer les résultats par score et cible
        filtered_keywords = [(kw[0], kw[1], txt_file[12:14]) for kw in entities_filtered if kw[1] > 0.5]
        keywords_ODD.extend(filtered_keywords)

    # Stockage des résultats en dataframe
    df = pd.DataFrame(keywords_ODD, columns=["Mots-cles", "Scores", "Cibles"])
    grouped = df.groupby("Cibles")
    results_dfs = []
    for cible, group in grouped :
        df_targets = pd.DataFrame({f"Cible {cible}": group["Mots-cles"].values, "Scores": group["Scores"].values})
        results_dfs.append(df_targets)
    
    final_results = pd.concat(results_dfs, axis=1)
    
    display(final_results)
    
    print(f"...Fin de traitement de l'ODD {odd_number}\n")


entities_extractions("../MedaDocx/ODD01")
# Out:
# Début de traitement de l'ODD 01...
#                  Cible 01  Scores                      Cible 02  Scores  \
# 0   international poverty  0.6882                  poverty rate  0.7206
# 1          global poverty  0.6793                  poverty line  0.6732
# 2       assessing poverty  0.6189              national poverty  0.6481
# 3        defining poverty  0.6014               country poverty  0.6478
# 4        poverty measures  0.5812             assessing poverty  0.6347
# 5            poverty line  0.5672              defining poverty  0.6229
# 6         poverty poverty  0.5667                 rural poverty  0.6204
# 7           value poverty  0.5537             poverty according  0.5986
# 8           poverty given  0.5527      multidimensional poverty  0.6296
# 9           world poorest  0.5524               poverty measure  0.6171
# 10           poverty rate  0.7192  multidimensional deprivation  0.6111
# 11           poverty line  0.6564         deprivations measured  0.5865
# 12      household poverty  0.6523            poverty indicators  0.5822
# 13     poverty households  0.6446         weighted deprivations  0.5437
# 14         levels poverty  0.6398   households multidimensional  0.5076
# 15    expenditure poverty  0.6379             poverty headcount  0.5024
# 16        working poverty  0.6322                           NaN     NaN
# 17  international poverty  0.6303                           NaN     NaN
# 18            poor income  0.6109                           NaN     NaN
# 19                poverty  0.5981                           NaN     NaN
# 20                    NaN     NaN                           NaN     NaN
# 21                    NaN     NaN                           NaN     NaN
# 22                    NaN     NaN                           NaN     NaN
# 23                    NaN     NaN                           NaN     NaN
#
#              Cible 03  Scores           Cible 04  Scores  \
# 0   social protection  0.6254     water services  0.5502
# 1     coverage social  0.5864   water sanitation  0.5024
# 2    social insurance  0.5758        land tenure  0.5982
# 3   social protection  0.6265        tenure land  0.5825
# 4    social insurance  0.5443  secure landholder  0.5751
# 5    insurance social  0.5235      tenure rights  0.5526
# 6                 NaN     NaN    tenure security  0.5319
# 7                 NaN     NaN        land rights  0.5311
# 8                 NaN     NaN      secure tenure  0.5130
# 9                 NaN     NaN                NaN     NaN
# 10                NaN     NaN                NaN     NaN
# 11                NaN     NaN                NaN     NaN
# 12                NaN     NaN                NaN     NaN
# 13                NaN     NaN                NaN     NaN
# 14                NaN     NaN                NaN     NaN
# 15                NaN     NaN                NaN     NaN
# 16                NaN     NaN                NaN     NaN
# 17                NaN     NaN                NaN     NaN
# 18                NaN     NaN                NaN     NaN
# 19                NaN     NaN                NaN     NaN
# 20                NaN     NaN                NaN     NaN
# 21                NaN     NaN                NaN     NaN
# 22                NaN     NaN                NaN     NaN
# 23                NaN     NaN                NaN     NaN
#
#                  Cible 05  Scores                 Cible 0a  Scores  \
# 0      affected disasters  0.5608               oda grants  0.6402
# 1         affected people  0.5360              income oecd  0.5559
# 2           economic loss  0.6234           assistance oda  0.5364
# 3           loss monetary  0.5053              defines oda  0.5157
# 4        sendai framework  0.6154      development welfare  0.5157
# 5    framework indicators  0.5400        poverty reduction  0.5094
# 6       agreements sendai  0.5217        expenditure cofog  0.6398
# 7   implementation sendai  0.5128   government expenditure  0.6178
# 8           disaster risk  0.6066   expenditure government  0.6007
# 9      integrate disaster  0.5333      expenditure defined  0.5646
# 10        policy disaster  0.5330       government finance  0.5280
# 11      relating disaster  0.5180        fiscal activities  0.5239
# 12          2030 disaster  0.5038         fiscal indicator  0.5226
# 13                    NaN     NaN        kinds expenditure  0.5190
# 14                    NaN     NaN     expenditure services  0.5130
# 15                    NaN     NaN  educational expenditure  0.7062
# 16                    NaN     NaN    expenditure education  0.6466
# 17                    NaN     NaN   government expenditure  0.6141
# 18                    NaN     NaN     includes expenditure  0.5868
# 19                    NaN     NaN       expenditure funded  0.5380
# 20                    NaN     NaN      country expenditure  0.5363
# 21                    NaN     NaN       education includes  0.5298
# 22                    NaN     NaN              expenditure  0.5296
# 23                    NaN     NaN       expenditure levels  0.5038
#
#                     Cible 0b  Scores
# 0           monetary poverty  0.6687
# 1              poor monetary  0.5710
# 2        consumption poverty  0.5270
# 3         poverty determined  0.5266
# 4             poverty levels  0.5135
# 5   expenditures governments  0.5055
# 6                    poverty  0.5002
# 7                        NaN     NaN
# 8                        NaN     NaN
# 9                        NaN     NaN
# 10                       NaN     NaN
# 11                       NaN     NaN
# 12                       NaN     NaN
# 13                       NaN     NaN
# 14                       NaN     NaN
# 15                       NaN     NaN
# 16                       NaN     NaN
# 17                       NaN     NaN
# 18                       NaN     NaN
# 19                       NaN     NaN
# 20                       NaN     NaN
# 21                       NaN     NaN
# 22                       NaN     NaN
# 23                       NaN     NaN
# ...Fin de traitement de l'ODD 01

# %%
# if __name__ == "__main__":
#     # Exécution de tous les ODD
#     path = "../MedaDocx"
#     odd_files = os.listdir(path)
#     for odd_file in odd_files:
#         entities_extractions(f"{path}/{odd_file}")
#         print("----------------------------------------------------------------------------------------------------------")
